# %% [markdown]
# # Clustering
#
# Runs K-Means, Agglomerative Clustering, and DBSCAN.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent
sys.path.append(str(ROOT))

from src.run_clustering import run

run('data/raw/heart.csv')
