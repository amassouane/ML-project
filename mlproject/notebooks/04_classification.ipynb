# %% [markdown]
# # Classification
#
# Trains 7 supervised models with GridSearchCV and logs results with MLflow.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent
sys.path.append(str(ROOT))

from src.run_classification import run

run('data/raw/heart.csv')
