# %% [markdown]
# # Dimensionality Reduction
#
# Runs PCA, t-SNE, and NMF and saves plots in `reports/figures/`.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent
sys.path.append(str(ROOT))

from src.run_dimensionality import run

run('data/raw/heart.csv')
